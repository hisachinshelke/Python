# %%
from mpackage import mathy

# %%
mathy.addn(2,5)
# Out:
# 7

# %%
from mpackage.submpackage import advmathy

# %%
advmathy.multm(10,5)
# Out:
# 50

# %%
from mpackage.submpackage import *

# %%
advmathy.devm(10,5)
# Out:
# 2.0

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
from math import sqrt

# %%
sqrt(100)
# Out:
# 10.0
