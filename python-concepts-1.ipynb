# %%
# Lecture 19

# %%
# Bitwise operator concepts

# %%
print(bin(0b1111))
# Out:
# 0b1111

# %%
# complement ~ Operator
~13
# Out:
# -14

# %%
~50
# Out:
# -51

# %%
# in heap memoery - never stores the negative values, so using complement operator to store -ve values

# %%
# AND and OR operator

# %%
# AND operator

# 12 - 1100
# 13 - 1101
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 & 1
# Out:
# 1

# %%
bin(35)
# Out:
# '0b100011'

# %%
bin(40)
# Out:
# '0b101000'

# %%
35 & 40
# Out:
# 32

# %%
35 | 40
# Out:
# 43

# %%
# XOR - Exclusive OR (^)
# 00-0
# 11-0
# 01-1
# 10-1

# %%
12 ^ 13
# Out:
# 1

# %%
25 ^ 30
# Out:
# 7

# %%
# LEFT SHIFT << means gain the bits
# 33.00 = 33.0000
10 << 1 # 1010 << 1 => 10100 = 20
# 1 means one 0, 2 measn 2 zeros
# Out:
# 20

# %%
10 << 1
# Out:
# 20

# %%
10 << 2 # 1010 00 =
# Out:
# 40

# %%
# RIGHT SHIFT >> "loose zeros"
10 << 3 # 1010 000
# Out:
# 80

# %%
10 >> 2 # 1010 => loose 2 bits => 10
# Out:
# 2

# %%
10 >>1 # 1010 => 101 = 4
# Out:
# 5

# %%
10 >> 3 # 1010 => 1 = 1
# Out:
# 1

# %%
20 >> 4
# Out:
# 1

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
# import Math function

# %%
import math

# %%
x = math.sqrt(25)
x
# Out:
# 5.0

# %%
x1 = math.sqrt(15)
x1
# Out:
# 3.872983346207417

# %%
x1 = math.sqrt(16)
x1
# Out:
# 4.0

# %%
# floor (lower) and ceil - upper value

# %%
math.floor(3.87)
# Out:
# 3

# %%
math.ceil(3.87)
# Out:
# 4

# %%
math.pow(3,2) # 3 to power 2
# Out:
# 9.0

# %%
math.pi # pie value
# Out:
# 3.141592653589793

# %%
math.e # epselon
# Out:
# 2.718281828459045

# %%
import math as m

# %%
m.sqrt(100)
# Out:
# 10.0

# %%
m.ceil(3.05)
# Out:
# 4

# %%
m.pi
# Out:
# 3.141592653589793

# %%
from math import sqrt, pow, pi

# %%
sqrt(36)
# Out:
# 6.0

# %%
pi
# Out:
# 3.141592653589793

# %%
pow(3,4)
# Out:
# 81.0

# %%
from math import *

# %%
sqrt(100)
# Out:
# 10.0

# %%
pi
# Out:
# 3.141592653589793

# %%
e
# Out:
# 2.718281828459045

# %%
sin(90)
# Out:
# 0.8939966636005579

# %%
sin(45)
# Out:
# 0.8509035245341184

# %%
round(pi)
# Out:
# 3

# %%
# user input function
# input function

# %%
x = input()

# %%
x
# Out:
# 'Hello World'

# %%
x = input()
y = input()
z = x + y
z
# Out:
# '1020'

# %%
# input function by default understands String 'str'

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %%
type(z)
# Out:
# str

# %%
x = input("Enter first number = ")
y = input("Enter second number = ")
a1 = int(x)
a2 = int(y)
z1 = a1 + a2
print(z1)
# Out:
# 30

# %%
type(z1)
# Out:
# int

# %%
x1 = int(input("Enter first number: "))
y1 = int(input("Enter second number: "))
result = x1 + y1
print(result)
# Out:
# 50

# %%
type(result)
# Out:
# int

# %%
# Senapati Sir number = 9353157658

# %%
# input function by default is string type

# %%
st = input()

# %%
st
# Out:
# 'Hello World'

# %%
st[0]
# Out:
# 'H'

# %%
st[0:5]
# Out:
# 'Hello'

# %%
st = input()

# %%
st
# Out:
# '1+2+3'

# %%
print(type(st))
# Out:
# <class 'str'>

# %%
result = eval(input())
result
# Out:
# 60

# %%
result = eval(input())
result
# Out:
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[110], line 1
#     result = eval(input())
#
#   File <string>:1
#     Hello World + 10
#           ^
# SyntaxError: invalid syntax

# %%
#eval # evaluating the expression and no need to typecast to int

# %%
#_______---

# %%
# test.py
import sys
x = int(sys.argv[1])
y = int(sys.argv[2])
z = x + y
print(z)

# python test.py 10 20
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 2
#       1 import sys
# ----> 2 x = int(sys.argv[1])
#       3 y = int(sys.argv[2])
#       4 z = x +y
#
# ValueError: invalid literal for int() with base 10: '--f=/Users/sachinshelke/Library/Jupyter/runtime/kernel-v388163d2a34f527fa53db9ef106e4f88e47021e60.json'

# %%
# test.py
import sys
x = int(sys.argv[1])
y = int(sys.argv[2])
m = int(sys.argv[3])
z = x + y + m
print(z)

# python test.py 10 20 30
